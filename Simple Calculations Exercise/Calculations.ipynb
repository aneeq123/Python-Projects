# %%
#Python Exercise


#Define Main Function
def main():
  
  instructions() #call the Instruction Function
  menu()         #Call the Menu Function
 
 
  
  #Functions#
  
  #Define Instruction function
def instructions():
    print('A dog food company Discount Calculator\nPlease follow  the on screen instructions')
    
    
  #Define Menu function  
def menu():
  print('----------------------------------------------------\nNumber of Bags\t\t\tRate of Discount\n----------------------------------------------------')
  print('Less than 20\t\t\t 0%\nfrom 20-79\t\t\t 6%\nFrom 80-109\t\t\t 12%\n110 or more\t\t\t 20%')
  password = input('Enter your  password ')
  checkpassword(password) #call checkpassword Function 
  

  
  
  #Define checkpassword function  
def checkpassword(pwd):

  
  
  if pwd == 'QWERTY':
    print('Password accepted')
    cost() #Call the cost function if the password approved
  else:
   
      print('Password not accepted- Try again')
      menu() #Call the menu function if password declined
    

 #Define Cost Function 
def cost():
  
  bags =  int(input('Enter number of bags purchased '))
  
  if bags <= 20:
    print( 'The rate of Discount is 0%')
  elif bags <= 79:
    print( 'The rate of Discount is 6%')
  elif bags <= 109:
    print( 'The rate of Discount is 12%')
  else:
    print( 'The rate of Discount is 20%')
    
    
    #Calculate the Total Cost
  price = bags * 6.75
  print ('Price:', "$" + "{0:,.2f}".format(price))

  
  
  
  # Calculate the rate of discount
  discount = price 


  if bags <= 20:
    print( 'Discount:', "$" + "{0:,.2f}".format(discount * 0.00))
  elif bags <= 79:
    print( 'Discount:',"$" + "{0:,.2f}".format(discount * 0.06))
  elif bags <= 109:
    print( 'Discount:', "$" + "{0:,.2f}".format(discount * 0.12))
  else:
    print( 'Discount:', "$" + "{0:,.2f}".format(discount * 0.20))
    
    
  #Calculate the final Price
  TP = price 

  if bags <= 20:
    print( 'Total amount due:', "$" + "{0:,.2f}".format( TP - discount * 0.00))
  elif bags <= 79:
    print( 'Total amount due:', "$" + "{0:,.2f}".format( TP - discount * 0.06))
  elif bags <= 109:
    print( 'Total amount due:', "$" + "{0:,.2f}".format( TP - discount * 0.12))
  else:
    print( 'Total amount due:', "$" + "{0:,.2f}".format( TP - discount * 0.20))

  
main() #Call the main function
# Out:
# A dog food company Discount Calculator
# Please follow  the on screen instructions
# ----------------------------------------------------
# Number of Bags			Rate of Discount
# ----------------------------------------------------
# Less than 20			 0%
# from 20-79			 6%
# From 80-109			 12%
# 110 or more			 20%
# Enter your  password QWERTY
# Password accepted
# Enter number of bags purchased 75
# The rate of Discount is 6%
# Price: $506.25
# Discount: $30.38
# Total amount due: $475.88
